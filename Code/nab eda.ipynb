# %%
import pandas as pd

# %%
pss = pd.read_csv(r"C:\Users\moham\Downloads\NbaStats\Player Season Info.csv")

# %%
ppg = pd.read_csv(r"C:\Users\moham\Downloads\NbaStats\Player Per Game.csv")

# %%
players_stats = pd.merge(pss, ppg, on= 'seas_id', how='inner').sort_values(by='pts_per_game', ascending=False)

# %%
players_stats[['player_x' ,'g', 'fg_percent', 'e_fg_percent', 'ft_percent', 'pts_per_game']].groupby('player_x').agg({'g': 'sum', 'fg_percent': 'mean', 'e_fg_percent': 'mean', 'ft_percent': 'mean', 'pts_per_game': 'mean'}).sort_values(by='pts_per_game', ascending=False)

# %%
ppg[ppg['g'].agg('sum') < 100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ppg['g'] = ppg['g'].apply(lambda x: int(x))

# %%
test = ppg[(ppg['g'] >= 100)]
print(test)
# Out:
# Empty DataFrame
# Columns: [seas_id, season, player_id, player, birth_year, pos, age, experience, lg, tm, g, gs, mp_per_game, fg_per_game, fga_per_game, fg_percent, x3p_per_game, x3pa_per_game, x3p_percent, x2p_per_game, x2pa_per_game, x2p_percent, e_fg_percent, ft_per_game, fta_per_game, ft_percent, orb_per_game, drb_per_game, trb_per_game, ast_per_game, stl_per_game, blk_per_game, tov_per_game, pf_per_game, pts_per_game]
# Index: []
#
# [0 rows x 35 columns]

# %%
pd.set_option('display.max_rows', 200)
ppg.head(100)
# Out:
#     seas_id  season  player_id              player  birth_year pos   age  \
# 0     31136    2024       5025          A.J. Green         NaN  SG  24.0
# 1     31137    2024       5027          AJ Griffin         NaN  SF  20.0
# 2     31138    2024       4219        Aaron Gordon         NaN  PF  28.0
# 3     31139    2024       4582       Aaron Holiday         NaN  PG  27.0
# 4     31140    2024       4805       Aaron Nesmith         NaN  SF  24.0
# 5     31141    2024       4900       Aaron Wiggins         NaN  SG  25.0
# 6     31142    2024       4688   Admiral Schofield         NaN  PF  26.0
# 7     31143    2024       3734          Al Horford         NaN   C  37.0
# 8     31144    2024       3982          Alec Burks         NaN  SG  32.0
# 9     31145    2024       4806  Aleksej Pokusevski         NaN  PF  22.0
# 10    31146    2024       4465         Alex Caruso         NaN  SG  29.0
# 11    31147    2024       5109          Alex Fudge         NaN  SF  20.0
# ...

# %%
ppg.groupby('player').g.agg(["sum"]).sort_values(by='sum', ascending=False).head(100)
# Out:
#                       sum
# player
# Eddie Johnson        2078
# Vince Carter         1691
# Kevin Willis         1644
# Gerald Henderson     1628
# Robert Parish        1611
# George Johnson       1582
# Mike Dunleavy        1574
# Andre Miller         1562
# Kareem Abdul-Jabbar  1560
# Moses Malone         1537
# Jason Kidd           1526
# Dirk Nowitzki        1522
# Kevin Garnett        1509
# John Stockton        1504
# Joe Johnson          1490
# Karl Malone          1476
# Mark Jackson         1461
# Clifford Robinson    1451
# Kyle Korver          1444
# LeBron James         1440
# Gary Payton          1415
# Juwan Howard         1412
# Jason Terry          1410
# Jeff Green           1404
# Otis Thorpe          1401
# Artis Gilmore        1400
# Tim Duncan           1392
# Jamal Crawford       1392
# Reggie Miller        1389
# Derek Fisher         1383
# Nazr Mohammed        1377
# Ray Allen            1376
# Caldwell Jones       1375
# Sam Perkins          1365
# ...

# %%
ppg[(ppg.groupby('player').g.agg(["sum"]) >= 100)].head(10)
# Out:
#    seas_id  season  player_id player  birth_year  pos  age  experience   lg  \
# 0      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 1      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 2      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 3      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 4      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 5      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 6      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 7      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 8      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
# 9      NaN     NaN        NaN    NaN         NaN  NaN  NaN         NaN  NaN
#
#     tm  ...  ft_percent  orb_per_game  drb_per_game  trb_per_game  \
# ...

# %%
ppg[ppg.groupby('player').g.agg["sum"] & ('sum' >= 100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 ppg[ppg.groupby('player').g.agg["sum"] & ('sum' >= 100)]
#
# TypeError: 'method' object is not subscriptable

# %%
ppg[ppg.g > 80].head(10)
# Out:
#      seas_id  season  player_id              player  birth_year pos   age  \
# 640    30601    2023       4492       Derrick White         NaN  SG  28.0
# 718    30678    2023       4089     Harrison Barnes         NaN  PF  30.0
# 721    30681    2023       4837   Immanuel Quickley         NaN  PG  23.0
# 723    30683    2023       4627  Isaiah Hartenstein         NaN   C  24.0
# 799    30758    2023       4638        Jevon Carter         NaN  PG  27.0
# 822    30781    2023       4737        Jordan Poole         NaN  PG  23.0
# 874    30833    2023       4854   Kenyon Martin Jr.         NaN  SF  22.0
# 892    30851    2023       4342        Kevon Looney         NaN   C  26.0
# 932    30892    2023       4426       Malik Beasley         NaN  SG  26.0
# 967    30927    2023       4658       Mikal Bridges         NaN  SF  26.0
#
#      experience   lg   tm  ...  ft_percent  orb_per_game  drb_per_game  \
# 640           6  NBA  BOS  ...       0.875           0.6           2.9
# ...

# %%
games = ppg.groupby('player').g.agg(["sum"]).sort_values(by='sum', ascending= False)

# %%
games
# Out:
#                    sum
# player
# Eddie Johnson     2078
# Vince Carter      1691
# Kevin Willis      1644
# Gerald Henderson  1628
# Robert Parish     1611
# ...                ...
# Rich Dumas           1
# Rich Eichhorst       1
# Antonio Anderson     1
# Alex Scales          1
# Penny Early          1
#
# [5129 rows x 1 columns]

# %%
ppgg = pd.merge(ppg, games, on= 'player', how= 'inner' )

# %%
ppgg
# Out:
#        seas_id  season  player_id          player  birth_year  pos   age  \
# 0        31136    2024       5025      A.J. Green         NaN   SG  24.0
# 1        30458    2023       5025      A.J. Green         NaN   SG  23.0
# 2        31137    2024       5027      AJ Griffin         NaN   SF  20.0
# 3        30467    2023       5027      AJ Griffin         NaN   SF  19.0
# 4        31138    2024       4219    Aaron Gordon         NaN   PF  28.0
# ...        ...     ...        ...             ...         ...  ...   ...
# 31628      199    1947        156   Virgil Vaughn         NaN  F-C  28.0
# 31629      200    1947        157     Walt Miller         NaN    F  31.0
# 31630      201    1947        158   Warren Fenley         NaN    F  24.0
# 31631      202    1947        159   Wilbert Kautz         NaN  G-F  31.0
# 31632      203    1947        160  Woody Grimshaw         NaN    G  27.0
#
#        experience   lg   tm  ...  orb_per_game  drb_per_game  trb_per_game  \
# ...

# %%
ppgg.set_alias({"sum" : 'total_games'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\392356588.py in ?()
# ----> 1 ppgg.set_alias({"sum" : 'total_games'})
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_alias'

# %%
ppgg[["player", "total_games", "fg_percent", "e_fg_percent", "ft_percent", "pts_per_game"]].groupby('player').agg({"fg_percent": "mean", "e_fg_percent": "mean", "ft_percent": "mean", "pts_per_game": "mean"}).sort_values(by='e_fg_percent', ascending=False).head(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 ppgg[["player", "total_games", "fg_percent", "e_fg_percent", "ft_percent", "pts_per_game"]].groupby('player').agg({"fg_percent": "mean", "e_fg_percent": "mean", "ft_percent": "mean", "pts_per_game": "mean"}).sort_values(by='e_fg_percent', ascending=False).head(100)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
ppgg
# Out:
#        seas_id  season  player_id          player  birth_year  pos   age  \
# 0        31136    2024       5025      A.J. Green         NaN   SG  24.0
# 1        30458    2023       5025      A.J. Green         NaN   SG  23.0
# 2        31137    2024       5027      AJ Griffin         NaN   SF  20.0
# 3        30467    2023       5027      AJ Griffin         NaN   SF  19.0
# 4        31138    2024       4219    Aaron Gordon         NaN   PF  28.0
# ...        ...     ...        ...             ...         ...  ...   ...
# 31628      199    1947        156   Virgil Vaughn         NaN  F-C  28.0
# 31629      200    1947        157     Walt Miller         NaN    F  31.0
# 31630      201    1947        158   Warren Fenley         NaN    F  24.0
# 31631      202    1947        159   Wilbert Kautz         NaN  G-F  31.0
# 31632      203    1947        160  Woody Grimshaw         NaN    G  27.0
#
#        experience   lg   tm  ...  orb_per_game  drb_per_game  trb_per_game  \
# ...

# %%
ppg.set_alias({"player": "Player"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\299044360.py in ?()
# ----> 1 ppg.set_alias({"player": "Player"})
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_alias'

# %%
games.rename(columns= {"sum" : "total_games"})
# Out:
#                   total_games
# player
# Eddie Johnson            2078
# Vince Carter             1691
# Kevin Willis             1644
# Gerald Henderson         1628
# Robert Parish            1611
# ...                       ...
# Rich Dumas                  1
# Rich Eichhorst              1
# Antonio Anderson            1
# Alex Scales                 1
# Penny Early                 1
#
# [5129 rows x 1 columns]

# %%
games
# Out:
#                    sum
# player
# Eddie Johnson     2078
# Vince Carter      1691
# Kevin Willis      1644
# Gerald Henderson  1628
# Robert Parish     1611
# ...                ...
# Rich Dumas           1
# Rich Eichhorst       1
# Antonio Anderson     1
# Alex Scales          1
# Penny Early          1
#
# [5129 rows x 1 columns]

# %%
games = games.rename(columns= {"sum" : "total_games"})

# %%
games
# Out:
#                   total_games
# player
# Eddie Johnson            2078
# Vince Carter             1691
# Kevin Willis             1644
# Gerald Henderson         1628
# Robert Parish            1611
# ...                       ...
# Rich Dumas                  1
# Rich Eichhorst              1
# Antonio Anderson            1
# Alex Scales                 1
# Penny Early                 1
#
# [5129 rows x 1 columns]

# %%
ppgg = pd.merge(ppg, games, on = 'player', how = 'inner')

# %%
ppgg[["player", "total_games", "pts_per_game"]]
# Out:
#                player  total_games  pts_per_game
# 0          A.J. Green           46           2.8
# 1          A.J. Green           46           4.4
# 2          AJ Griffin           83           2.7
# 3          AJ Griffin           83           8.9
# 4        Aaron Gordon          662          13.1
# ...               ...          ...           ...
# 31628   Virgil Vaughn           17           2.6
# 31629     Walt Miller           12           1.9
# 31630   Warren Fenley           33           2.6
# 31631   Wilbert Kautz           50           5.1
# 31632  Woody Grimshaw           21           2.9
#
# [31633 rows x 3 columns]

# %%
ppgg[["player", "total_games", "fg_percent", 'e_fg_percent', "ft_percent", "pts_per_games"]].groupby("player").agg({"fg": "mean", "e_fg_percent": "mean", "ft_percent": "mean", "pts_per_game": "mean"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 ppgg[["player", "total_games", "fg_percent", 'e_fg_percent', "ft_percent", "pts_per_games"]].groupby("player").agg({"fg": "mean", "e_fg_percent": "mean", "ft_percent": "mean", "pts_per_game": "mean"})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
ppgg[["player", "total_games", "fg_percent", "e_fg_percent", "ft_percent", "pts_per_game"]].groupby("player").sort_values(by="fg_percent", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 ppgg[["player", "total_games", "fg_percent", "e_fg_percent", "ft_percent", "pts_per_game"]].groupby("player").sort_values(by="fg_percent", ascending = False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
ppgg[["player", "total_games", "fg_percent", 'e_fg_percent', "ft_percent", "pts_per_game"]].groupby("player").agg({"total_games": "sum" ,"fg_percent": "mean", "e_fg_percent": "mean", "ft_percent": "mean", "pts_per_game": "mean"}).sort_values(by="fg_percent", ascending=False)
# Out:
#                      total_games  fg_percent  e_fg_percent  ft_percent  \
# player
# Steven Hill                    1         1.0           1.0         NaN
# Randy Holcomb                  4         1.0           1.0         NaN
# Chad Gallagher                 2         1.0           1.0         NaN
# Dave Scholz                    1         1.0           1.0         NaN
# Tyson Wheeler                  1         1.0           1.5         0.5
# ...                          ...         ...           ...         ...
# Taylor Hendricks               1         NaN           NaN         0.5
# Trevor Winter                  1         NaN           NaN         NaN
# Trey McKinney-Jones            1         NaN           NaN         NaN
# Tyler Hall                     1         NaN           NaN         NaN
# Yvon Joseph                    1         NaN           NaN         1.0
#
#                      pts_per_game
# player
# Steven Hill                   2.0
# ...
